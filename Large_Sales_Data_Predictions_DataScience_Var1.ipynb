# %% [markdown]
# ### PANDAS
#
# https://github.com/KeithGalli/Pandas-Data-Science-Tasks
#
# ### Data Analysis:
#
#     1. Data import folder or no of files
#     2. Merge all files to make single file
#     3. Read single file through Pandas and find out NA data
#     4. Deleted rows or modified where ever NA data
#     5. Create month column and take the month information from order
#     6. Calculate month wise sales
#     7Q. Plot mont vs salse on last year with the help of Matplotlib.pyplot
#
#
#     8. Sales = Quantity Orderd * Price Each
#
#     9. Quantity Orderd * Price Each--convert sting to numeric data
#
#     10. Plot Month Vs Sales
#
# ### Error
#
# https://www.stechies.com/valueerror-invalid-literal-int-base-10/

# %%
import os
import pandas as pd

# %%
# 1 data import from all excel files, read and merge as one file


path = "./Sales_Data"


files =  [file for file in os.listdir(path) if not file.startswith('.')]

all_months_data = pd.DataFrame()

for file in files:
    Excel_data = pd.read_csv(path+"/"+file)
    all_months_data = pd.concat([all_months_data,Excel_data])

all_months_data.to_csv("all_data_Copy.csv",index=False)

# %%
# read CSV file as recently saved

all_data = pd.read_csv("all_data_Copy.csv")

all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
# modification on data

all_data.shape
# Out:
# (186850, 6)

# %%
# bar graph

nan_df = all_data[all_data.isna().any(axis=1)]

display(nan_df)
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1           NaN     NaN              NaN        NaN        NaN
# 356         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1433        NaN     NaN              NaN        NaN        NaN
# 1553        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185176      NaN     NaN              NaN        NaN        NaN
# 185438      NaN     NaN              NaN        NaN        NaN
# 186042      NaN     NaN              NaN        NaN        NaN
# 186548      NaN     NaN              NaN        NaN        NaN
# 186826      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1                   NaN
# 356                 NaN
# 735                 NaN
# 1433                NaN
# 1553                NaN
# ...                 ...
# 185176              NaN
# ...

# %%
nan_df.shape
# Out:
# (545, 6)

# %%
all_data = all_data.dropna(how='all')

all_data.shape
# Out:
# (186305, 6)

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# https://www.stechies.com/valueerror-invalid-literal-int-base-10/

# %%
#all_data =all_data[ all_data["Order Date"].str[0:2]!='or']

#all_data.head()
#all_data = all_data[all_data['Order Date'].str[0:2]!='Or']

# %%
#all_data["Quantity Ordered"] =pd.to_numeric(all_data["Quantity Ordered"])
#all_data["Quantity Ordered"].dtype
#all_data["Quantity Ordered"] = all_data["Quantity Ordered"].astype('int32')

#all.data["Price Each"] = pd.to_numeric(all_data["Price Each"])

# %%
#all_data =all_data[ all_data["Order Date"].str[0:2]!='or']
all_data["Month"] = all_data["Order Date"].str[0:2]
#all_data['Month'] = all_data['Month'].astype('int32')
#all_data["Month"] = pd.to_numeric(all_data["Month"])
#all_data =all_data[ all_data["Order Date"].str[0:2]!='or']
#all_data["Month"].dtype
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %% [markdown]
# ### Error invalid literal for int() with base 10: 'Or'
#
# error occured during string to int direct conversion
#
# all_data['Month'] = all_data['Month'].astype('int32')
#
# solution:
#
# convert sting to numetic data  then int converted "Int32 or Int 64"
#
# all_data["Month"] = pd.to_numeric(all_data["Month"],errors='coerce')
#
# all_data['Month'] = all_data['Month'].astype('Int32')

# %%
all_data["Month"] = pd.to_numeric(all_data["Month"],errors='coerce')

all_data['Month'] = all_data['Month'].astype('Int64')

all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# ### Error Unable to parse string "Quantity Ordered" at position 517
#
# all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"])
#
# it doesnt workout string to numeric conversion with out "errors='coerce'"
#
#
#
# solution:
#
# https://stackoverflow.com/questions/42719749/pandas-convert-string-to-int
#
# all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"],errors='coerce')

# %%
all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"],errors='coerce')
all_data["Price Each"] = pd.to_numeric(all_data["Price Each"],errors='coerce')

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
all_data["Quantity Ordered"]=all_data['Quantity Ordered'].astype('Int32')  
all_data["Price Each"]=all_data['Price Each'].astype('float')

# %%
all_data.shape
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# ### Note:
#
# following command must be menioned Int or float

# %%
all_data["Sales per mongth"]=all_data['Quantity Ordered'].astype('Int32')*all_data["Price Each"].astype('float')

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#    Sales per mongth
# 0             23.90
# 2             99.99
# 3            600.00
# 4             11.99
# 5             11.99

# %%
all_data.groupby("Month").sum()
#all_data.head()
# Out:
#        Quantity Ordered    Price Each  Sales per mongth
# Month
# 1                 10903  1.811768e+06      1.822257e+06
# 2                 13449  2.188885e+06      2.202022e+06
# 3                 17005  2.791208e+06      2.807100e+06
# 4                 20558  3.367671e+06      3.390670e+06
# 5                 18667  3.135125e+06      3.152607e+06
# 6                 15253  2.562026e+06      2.577802e+06
# 7                 16072  2.632540e+06      2.647776e+06
# 8                 13448  2.230345e+06      2.244468e+06
# 9                 13109  2.084992e+06      2.097560e+06
# 10                22703  3.715555e+06      3.736727e+06
# 11                19798  3.180601e+06      3.199603e+06
# 12                28114  4.588415e+06      4.613443e+06

# %%
import matplotlib.pyplot as plt

months = range(1,13)
print(months)

plt.bar(months,all_data.groupby(['Month']).sum()["Sales per mongth"])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.show()
# Out:
# range(1, 13)
